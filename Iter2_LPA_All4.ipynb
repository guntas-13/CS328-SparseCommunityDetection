# %%
from Networks import *

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
k_values = [0.5, 0.3, 0.2, 0.1, 0.05, 0.01]

# %%
sparseFunctions = [("Edge Betweenness", edge_betweenness_sparsification), ("Random", edge_random_sparsification), ("Edge Jaccard JC", edge_jaccard_sparsification), (r"$^*$Edge Local Search L-Spar", edge_L_Spar_sparsification), ("Clustering Coefficients", clustering_coeffs_edge_sampling), ("Metropolis-Hastings", metropolis_hastings_algorithm), ("Effective Resistance Sampling", effective_resistance_sampling_2)]
sparseFunctionNames = ["Edge Betweenness", "Random", "Edge Jaccard JC", "Edge Local Search L-Spar", "Clustering Coefficients", "Metropolis-Hastings", "Effective Resistance Sampling"]

# %%
sparseFunctionNames
# Out:
# ['Edge Betweenness',
#  'Random',
#  'Edge Jaccard JC',
#  'Edge Local Search L-Spar',
#  'Clustering Coefficients',
#  'Metropolis-Hastings',
#  'Effective Resistance Sampling']

# %%
sparseDBLPGraphsLouvain = plot_metrics_sparse(G_ind_DBLP, run_louvain(G_ind_DBLP), sparseFunctions, k_values, run_louvain, 0, "DBLP", "Louvain Algorithm")

# %%
sparseDBLPGraphsLPA = plot_metrics_sparse(G_ind_DBLP, get_community_dict(run_lpa(G_ind_DBLP)), sparseFunctions, k_values, run_lpa, 1, "DBLP", "Label Propogation Algorithm")

# %%
sparseDBLPGraphsLPA, ari, nmi, mod, clust = plot_metrics_sparse(G_ind_DBLP, get_community_dict(run_lpa(G_ind_DBLP)), sparseFunctions, k_values, run_lpa, 1, "DBLP", "Label Propogation Algorithm")
createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "LPA", "DBLP")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sparseDBLPGraphsLPA, ari, nmi, mod, clust = plot_metrics_sparse(G_ind_DBLP, get_community_dict(run_lpa(G_ind_DBLP)), sparseFunctions, k_values, run_lpa, 1, "DBLP", "Label Propogation Algorithm")
#       2 createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "LPA", "DBLP")
#
# File ~/Desktop/JetBrains Projects/CS328-SparseCommunityDetection/Networks.py:255, in plot_metrics_sparse(G, ground_truth, sparseFunctions, k_values, AlgoFunction, flag, networkName, AlgoName)
#     253 for idx, (_, function) in enumerate(sparseFunctions):
#     254     for i, k in enumerate(k_values):
# --> 255         H = function(G, k)
#     256         predicted = AlgoFunction(H)
#     257         if (flag == 1):
#
# File ~/Desktop/JetBrains Projects/CS328-SparseCommunityDetection/Networks.py:155, in metropolis_hastings_algorithm(graph, sampling_ratio)
#     152 alpha = 0.3
#     154 H = nx.Graph()
# --> 155 while num_edges < int(graph.number_of_edges()*sampling_ratio):
#     156     if patience == 10:
#     157         current_node = np.random.choice(np.array(graph.nodes()))
#
# File ~/micromamba/lib/python3.9/site-packages/networkx/classes/graph.py:1959, in Graph.number_of_edges(self, u, v)
#    1913 """Returns the number of edges between two nodes.
#    1914
#    1915 Parameters
#    (...)
#    1956
#    1957 """
#    1958 if u is None:
# -> 1959     return int(self.size())
#    1960 if v in self._adj[u]:
#    1961     return 1
#
# File ~/micromamba/lib/python3.9/site-packages/networkx/classes/graph.py:1905, in Graph.size(self, weight)
#    1869 def size(self, weight=None):
#    1870     """Returns the number of edges or total of all edge weights.
#    1871
#    1872     Parameters
#    (...)
#    1903     6.0
#    1904     """
# -> 1905     s = sum(d for v, d in self.degree(weight=weight))
#    1906     # If `weight` is None, the sum of the degrees is guaranteed to be
#    1907     # even, so we can perform integer division and hence return an
#    1908     # integer. Otherwise, the sum of the weighted degrees is not
#    1909     # guaranteed to be an integer, so we perform "real" division.
#    1910     return s // 2 if weight is None else s / 2
#
# File ~/micromamba/lib/python3.9/site-packages/networkx/classes/graph.py:1905, in <genexpr>(.0)
#    1869 def size(self, weight=None):
#    1870     """Returns the number of edges or total of all edge weights.
#    1871
#    1872     Parameters
#    (...)
#    1903     6.0
#    1904     """
# -> 1905     s = sum(d for v, d in self.degree(weight=weight))
#    1906     # If `weight` is None, the sum of the degrees is guaranteed to be
#    1907     # even, so we can perform integer division and hence return an
#    1908     # integer. Otherwise, the sum of the weighted degrees is not
#    1909     # guaranteed to be an integer, so we perform "real" division.
#    1910     return s // 2 if weight is None else s / 2
#
# File ~/micromamba/lib/python3.9/site-packages/networkx/classes/reportviews.py:530, in DegreeView.__iter__(self)
#     528 weight = self._weight
#     529 if weight is None:
# --> 530     for n in self._nodes:
#     531         nbrs = self._succ[n]
#     532         yield (n, len(nbrs) + (n in nbrs))
#
# File ~/micromamba/lib/python3.9/site-packages/networkx/classes/coreviews.py:310, in <genexpr>(.0)
#     308     node_ok_shorter = False
#     309 if node_ok_shorter:
# --> 310     return (n for n in self.NODE_OK.nodes if n in self._atlas)
#     311 return (n for n in self._atlas if self.NODE_OK(n))
#
# KeyboardInterrupt:

# %%
sparseDBLPGraphsInfomap = plot_metrics_sparse(G_ind_DBLP, get_community_dict(run_infomap(G_ind_DBLP).communities), sparseFunctions, k_values, run_infomap, 2, "DBLP", "Infomap Algorithm")

# %%
# pandas dataframe of an example 2d list

lit = [[0.5, 0.3, 0.2, 0.1, 0.05, 0.01], [0.5, 0.3, 0.2, 0.1, 0.05, 0.01], [0.5, 0.3, 0.2, 0.1, 0.05, 0.01], [0.5, 0.3, 0.2, 0.1, 0.05, 0.01], [0.5, 0.3, 0.2, 0.1, 0.05, 0.01], [0.5, 0.3, 0.2, 0.1, 0.05, 0.01]]
df = pd.DataFrame(lit, columns = ['0.5', '0.3', '0.2', '0.1', '0.05', '0.01'], index = ['Edge Betweenness', 'Random', 'Edge Jaccard JC', 'Edge Local Search L-Spar', 'Clustering Coefficients', 'Effective Resistance Sampling'])
df

# %%
# convert df to csv

df.to_csv('sparseDBLPGraphs.csv')

# %%
def createDataFrames(ari_values, nmi_values, modularity_values, clust_coeff_values, k_values, sparseFunctionNames, algorithm, dataset):
    ari_df = pd.DataFrame(ari_values, columns = k_values, index = sparseFunctionNames)
    nmi_df = pd.DataFrame(nmi_values, columns = k_values, index = sparseFunctionNames)
    modularity_df = pd.DataFrame(modularity_values, columns = k_values, index = sparseFunctionNames)
    clust_coeff_df = pd.DataFrame(clust_coeff_values, columns = k_values, index = sparseFunctionNames)
    
    ari_df.to_csv(f"{algorithm}_{dataset}_ARI.csv")
    nmi_df.to_csv(f"{algorithm}_{dataset}_NMI.csv")
    modularity_df.to_csv(f"{algorithm}_{dataset}_Modularity.csv")
    clust_coeff_df.to_csv(f"{algorithm}_{dataset}_Clustering_Coefficients.csv")
