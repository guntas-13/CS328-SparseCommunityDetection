# %% [markdown]
# # **EmailEU**

# %%
# !unzip Networks.zip

# %%
# !sudo apt install cm-super dvipng texlive-latex-extra texlive-latex-recommended
# !pip install pyvis
# !pip install 'cdlib[C]'

# %%
from Networks import *
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'bayanpy'}
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
k_values = [0.5, 0.3, 0.2, 0.1, 0.05, 0.01]
sparseFunctions = [("Edge Betweenness", edge_betweenness_sparsification), ("Random", edge_random_sparsification), ("Edge Jaccard JC", edge_jaccard_sparsification), (r"$^*$Edge Local Search L-Spar", edge_L_Spar_sparsification), ("Clustering Coefficients", clustering_coeffs_edge_sampling)]
sparseFunctionNames = ["Edge Betweenness", "Random", "Edge Jaccard JC", "Edge Local Search L-Spar", "Clustering Coefficients"]

# %% [markdown]
# ## **Louvain Algorithm**

# %%
sparseEUGraphsLouvain, ari, nmi, mod, clust = plot_metrics_sparse(G_eu, run_louvain(G_eu), sparseFunctions, k_values, run_louvain, 0, "EmailEU", "Louvain Algorithm")
createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "Louvain", "EmailEU")
# Out:
# DataFrames Created Successfully

# %% [markdown]
# ## **Label Propogation Algorithm**

# %%
sparseEUGraphsLPA, ari, nmi, mod, clust = plot_metrics_sparse(G_eu, get_community_dict(run_lpa(G_eu)), sparseFunctions, k_values, run_lpa, 1, "EmailEU", "Label Propogation Algorithm")
createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "LPA", "EmailEU")
# Out:
# DataFrames Created Successfully

# %% [markdown]
# ## **InfoMap Algorithm**

# %%
sparseEUGraphsInfomap, ari, nmi, mod, clust = plot_metrics_sparse(G_eu, get_community_dict(run_infomap(G_eu).communities), sparseFunctions, k_values, run_infomap, 2, "EmailEU", "Infomap Algorithm")
createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "Infomap", "EmailEU")
# Out:
# DataFrames Created Successfully

# %% [markdown]
# ## **Walk Trap Algorithm**

# %%
sparseEUGraphsWalkTrap, ari, nmi, mod, clust = plot_metrics_sparse(G_eu, get_community_dict(run_walktrap(G_eu).communities), sparseFunctions, k_values, run_walktrap, 2, "EmailEU", "WalkTrap Algorithm")
createDataFrames(ari, nmi, mod, clust, k_values, sparseFunctionNames, "Walktrap", "EmailEU")
